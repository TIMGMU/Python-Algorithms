# %% [markdown]
# ### Assignment 7 | Tim Nguyen | IT 309 | 11/21/2023

# %% [markdown]
# #### Edge list:

# %% [markdown]
# E{(1, 2, A3), (1, 3, B6), (1, 4, C5), (2, 5, D2), (3, 6, E4), (4, 7, F8), (5, 8, G4), (6, 8, H7), (6, 9, I1), (7, 9, J3), (7, 13, K12), (8, 10, L4), (9, 11, M5), (9, 12, N3), (10, 14, O6), (11, 14, P4), (12, 15, Q9), (13, 15, R8), (14, 16, S2), (15, 16, T3), (16, 17, U2)}

# %% [markdown]
# #### Adjacency Matrix:

# %% [markdown]
# ![image.png](attachment:9c098124-dcb8-4dcd-958a-6e08b1b4b2c9.png)

# %% [markdown]
# #### Adjacency List:

# %% [markdown]
# ![image.png](attachment:63d8c038-e1c6-4775-bd1c-6819f83db105.png)

# %% [markdown]
# ![image.png](attachment:75940a52-0d24-442b-b758-3ed61cabb144.png)

# %% [markdown]
# #### The critical path is 38 as highlighted above and the lowest completion time is 23, transversing A D G L O S U.

# %% [markdown]
# #### All possible paths taken

# %% [markdown]
# ![image.png](attachment:c2778338-521b-4a66-ac0e-9117191596b7.png)

# %% [markdown]
# Weighted outcome below showing path of most/least resistance and slack (EC-LC)

# %% [markdown]
# ![image.png](attachment:8ae63068-d614-428c-bab9-89d4afaefc0f.png)

# %% [markdown]
# #### EC/LC for every milestone shown below:

# %% [markdown]
# ![image.png](attachment:52ce7772-e54c-4f24-b448-d335db645aa1.png)

# %% [markdown]
# #### Slack per activity shown below calculated using EC-LC:

# %% [markdown]
# ![image.png](attachment:ba5b5330-8901-4ff4-ac81-7cc960f8a53a.png)
